# %% [markdown]
# <a href="https://colab.research.google.com/github/primozflander/TinyML_model_training/blob/main/train_hello_world_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Train a Simple TensorFlow Lite for Microcontrollers model
#
# This notebook demonstrates the process of training a 2.5 kB model using TensorFlow and converting it for use with TensorFlow Lite for Microcontrollers.
#
# Deep learning networks learn to model patterns in underlying data. Here, we're going to train a network to model data generated by a [sine](https://en.wikipedia.org/wiki/Sine) function. This will result in a model that can take a value, `x`, and predict its sine, `y`.
#
# The model created in this notebook is used in the [hello_world](https://github.com/tensorflow/tensorflow/tree/master/tensorflow/lite/micro/examples/hello_world) example for [TensorFlow Lite for MicroControllers](https://www.tensorflow.org/lite/microcontrollers/overview).
#
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/tensorflow/tensorflow/blob/master/tensorflow/lite/micro/examples/hello_world/train/train_hello_world_model.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/tensorflow/tensorflow/blob/master/tensorflow/lite/micro/examples/hello_world/train/train_hello_world_model.ipynb"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>

# %% [markdown]
# ## Configure Defaults

# %%
# Define paths to model files
import os
MODELS_DIR = 'models/'
if not os.path.exists(MODELS_DIR):
    os.mkdir(MODELS_DIR)
MODEL_TF = MODELS_DIR + 'model'
MODEL_NO_QUANT_TFLITE = MODELS_DIR + 'model_no_quant.tflite'
MODEL_TFLITE = MODELS_DIR + 'model.tflite'
MODEL_TFLITE_MICRO = MODELS_DIR + 'model.cc'

# %% [markdown]
# ## Setup Environment
#
# Install Dependencies

# %%
! pip install tensorflow==2.4.0
# Out:
# Collecting tensorflow==2.4.0
#   Downloading https://files.pythonhosted.org/packages/94/0a/012cc33c643d844433d13001dd1db179e7020b05ddbbd0a9dc86c38a8efa/tensorflow-2.4.0-cp37-cp37m-manylinux2010_x86_64.whl (394.7MB)
#      |████████████████████████████████| 394.7MB 37kB/s
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (0.2.0)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (1.15.0)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (0.36.2)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (3.12.4)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (1.12.1)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (0.3.3)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (1.6.3)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (3.7.4.3)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (3.3.0)
# Requirement already satisfied: tensorboard~=2.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (2.4.1)
# Requirement already satisfied: grpcio~=1.32.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (1.32.0)
# Requirement already satisfied: numpy~=1.19.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (1.19.5)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (2.4.0)
# Requirement already satisfied: h5py~=2.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (2.10.0)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (1.1.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (1.12)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (0.12.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (1.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.9.2->tensorflow==2.4.0) (56.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.0) (3.3.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.0) (1.8.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.0) (0.4.4)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.0) (1.30.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.0) (2.23.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.0) (2.0.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow==2.4.0) (4.0.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow==2.4.0) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0) (4.2.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0) (2.10)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.4->tensorflow==2.4.0) (3.4.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow==2.4.0) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0) (0.4.8)
# Installing collected packages: tensorflow
#   Found existing installation: tensorflow 2.4.1
#     Uninstalling tensorflow-2.4.1:
#       Successfully uninstalled tensorflow-2.4.1
# Successfully installed tensorflow-2.4.0

# %% [markdown]
# Import Dependencies

# %%
# TensorFlow is an open source machine learning library
import tensorflow as tf

# Keras is TensorFlow's high-level API for deep learning
from tensorflow import keras
# Numpy is a math library
import numpy as np
# Pandas is a data manipulation library 
import pandas as pd
# Matplotlib is a graphing library
import matplotlib.pyplot as plt
# Math is Python's math library
import math

# Set seed for experiment reproducibility
seed = 1
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### 1. Generate Data
#
# The code in the following cell will generate a set of random `x` values, calculate their sine values, and display them on a graph.

# %%
# Number of sample datapoints
SAMPLES = 1000

# Generate a uniformly distributed set of random numbers in the range from
# 0 to 2π, which covers a complete sine wave oscillation
x_values = np.random.uniform(
    low=0, high=2*math.pi, size=SAMPLES).astype(np.float32)

# Shuffle the values to guarantee they're not in order
np.random.shuffle(x_values)

# Calculate the corresponding sine values
y_values = np.sin(x_values).astype(np.float32)

# Plot our data. The 'b.' argument tells the library to print blue dots.
plt.plot(x_values, y_values, 'b.')
plt.show()

# %% [markdown]
# ### 2. Add Noise
# Since it was generated directly by the sine function, our data fits a nice, smooth curve.
#
# However, machine learning models are good at extracting underlying meaning from messy, real world data. To demonstrate this, we can add some noise to our data to approximate something more life-like.
#
# In the following cell, we'll add some random noise to each value, then draw a new graph:

# %%
# Add a small random number to each y value
y_values += 0.1 * np.random.randn(*y_values.shape)

# Plot our data
plt.plot(x_values, y_values, 'b.')
plt.show()

# %% [markdown]
# ### 3. Split the Data
# We now have a noisy dataset that approximates real world data. We'll be using this to train our model.
#
# To evaluate the accuracy of the model we train, we'll need to compare its predictions to real data and check how well they match up. This evaluation happens during training (where it is referred to as validation) and after training (referred to as testing) It's important in both cases that we use fresh data that was not already used to train the model.
#
# The data is split as follows:
#   1. Training: 60%
#   2. Validation: 20%
#   3. Testing: 20%
#
# The following code will split our data and then plots each set as a different color:

# %%
# We'll use 60% of our data for training and 20% for testing. The remaining 20%
# will be used for validation. Calculate the indices of each section.
TRAIN_SPLIT =  int(0.6 * SAMPLES)
TEST_SPLIT = int(0.2 * SAMPLES + TRAIN_SPLIT)

# Use np.split to chop our data into three parts.
# The second argument to np.split is an array of indices where the data will be
# split. We provide two indices, so the data will be divided into three chunks.
x_train, x_test, x_validate = np.split(x_values, [TRAIN_SPLIT, TEST_SPLIT])
y_train, y_test, y_validate = np.split(y_values, [TRAIN_SPLIT, TEST_SPLIT])

# Double check that our splits add up correctly
assert (x_train.size + x_validate.size + x_test.size) ==  SAMPLES

# Plot the data in each partition in different colors:
plt.plot(x_train, y_train, 'b.', label="Train")
plt.plot(x_test, y_test, 'r.', label="Test")
plt.plot(x_validate, y_validate, 'y.', label="Validate")
plt.legend()
plt.show()

# %% [markdown]
# ## Training

# %% [markdown]
# ### 1. Design the Model
# We're going to build a simple neural network model that will take an input value (in this case, `x`) and use it to predict a numeric output value (the sine of `x`). This type of problem is called a _regression_. It will use _layers_ of _neurons_ to attempt to learn any patterns underlying the training data, so it can make predictions.
#
# To begin with, we'll define two layers. The first layer takes a single input (our `x` value) and runs it through 8 neurons. Based on this input, each neuron will become _activated_ to a certain degree based on its internal state (its _weight_ and _bias_ values). A neuron's degree of activation is expressed as a number.
#
# The activation numbers from our first layer will be fed as inputs to our second layer, which is a single neuron. It will apply its own weights and bias to these inputs and calculate its own activation, which will be output as our `y` value.
#
# **Note:** To learn more about how neural networks function, you can explore the [Learn TensorFlow](https://codelabs.developers.google.com/codelabs/tensorflow-lab1-helloworld) codelabs.
#
# The code in the following cell defines our model using [Keras](https://www.tensorflow.org/guide/keras), TensorFlow's high-level API for creating deep learning networks. Once the network is defined, we _compile_ it, specifying parameters that determine how it will be trained:

# %%
# We'll use Keras to create a simple model architecture
model_1 = tf.keras.Sequential()

# First layer takes a scalar input and feeds it through 8 "neurons". The
# neurons decide whether to activate based on the 'relu' activation function.
model_1.add(keras.layers.Dense(16, activation='relu', input_shape=(1,)))

model_1.add(keras.layers.Dense(32, activation='relu', input_shape=(1,)))

model_1.add(keras.layers.Dense(16, activation='relu', input_shape=(1,)))

# Final layer is a single neuron, since we want to output a single value
model_1.add(keras.layers.Dense(1))

# Compile the model using the standard 'adam' optimizer and the mean squared error or 'mse' loss function for regression.
model_1.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %% [markdown]
# ### 2. Train the Model
# Once we've defined the model, we can use our data to _train_ it. Training involves passing an `x` value into the neural network, checking how far the network's output deviates from the expected `y` value, and adjusting the neurons' weights and biases so that the output is more likely to be correct the next time.
#
# Training runs this process on the full dataset multiple times, and each full run-through is known as an _epoch_. The number of epochs to run during training is a parameter we can set.
#
# During each epoch, data is run through the network in multiple _batches_. Each batch, several pieces of data are passed into the network, producing output values. These outputs' correctness is measured in aggregate and the network's weights and biases are adjusted accordingly, once per batch. The _batch size_ is also a parameter we can set.
#
# The code in the following cell uses the `x` and `y` values from our training data to train the model. It runs for 500 _epochs_, with 64 pieces of data in each _batch_. We also pass in some data for _validation_. As you will see when you run the cell, training can take a while to complete:

# %%
# Train the model on our training data while validating on our validation set
history_1 = model_1.fit(x_train, y_train, epochs=500, batch_size=64,
                        validation_data=(x_validate, y_validate))
# Out:
# Epoch 1/500
# 10/10 [==============================] - 1s 54ms/step - loss: 0.4821 - mae: 0.6142 - val_loss: 0.4392 - val_mae: 0.5726
# Epoch 2/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4249 - mae: 0.5539 - val_loss: 0.4194 - val_mae: 0.5563
# Epoch 3/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3909 - mae: 0.5288 - val_loss: 0.4015 - val_mae: 0.5463
# Epoch 4/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3974 - mae: 0.5376 - val_loss: 0.3845 - val_mae: 0.5363
# Epoch 5/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3670 - mae: 0.5169 - val_loss: 0.3648 - val_mae: 0.5226
# Epoch 6/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3384 - mae: 0.4958 - val_loss: 0.3434 - val_mae: 0.5092
# Epoch 7/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3325 - mae: 0.4904 - val_loss: 0.3064 - val_mae: 0.4861
# Epoch 8/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2821 - mae: 0.4564 - val_loss: 0.2680 - val_mae: 0.4531
# Epoch 9/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2467 - mae: 0.4267 - val_loss: 0.2364 - val_mae: 0.4285
# Epoch 10/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2113 - mae: 0.3963 - val_loss: 0.2063 - val_mae: 0.3995
# Epoch 11/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1879 - mae: 0.3717 - val_loss: 0.1843 - val_mae: 0.3770
# Epoch 12/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1726 - mae: 0.3535 - val_loss: 0.1651 - val_mae: 0.3490
# Epoch 13/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1539 - mae: 0.3329 - val_loss: 0.1530 - val_mae: 0.3297
# Epoch 14/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1337 - mae: 0.3025 - val_loss: 0.1459 - val_mae: 0.3156
# Epoch 15/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1281 - mae: 0.2903 - val_loss: 0.1406 - val_mae: 0.3016
# Epoch 16/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1250 - mae: 0.2818 - val_loss: 0.1379 - val_mae: 0.2943
# Epoch 17/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1256 - mae: 0.2789 - val_loss: 0.1359 - val_mae: 0.2897
# Epoch 18/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1213 - mae: 0.2694 - val_loss: 0.1407 - val_mae: 0.2944
# Epoch 19/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1268 - mae: 0.2730 - val_loss: 0.1344 - val_mae: 0.2773
# Epoch 20/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1154 - mae: 0.2629 - val_loss: 0.1331 - val_mae: 0.2820
# Epoch 21/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1186 - mae: 0.2625 - val_loss: 0.1308 - val_mae: 0.2784
# Epoch 22/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1125 - mae: 0.2531 - val_loss: 0.1289 - val_mae: 0.2717
# Epoch 23/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1063 - mae: 0.2476 - val_loss: 0.1289 - val_mae: 0.2753
# Epoch 24/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1176 - mae: 0.2578 - val_loss: 0.1273 - val_mae: 0.2671
# Epoch 25/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1149 - mae: 0.2538 - val_loss: 0.1284 - val_mae: 0.2741
# Epoch 26/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1146 - mae: 0.2579 - val_loss: 0.1238 - val_mae: 0.2675
# Epoch 27/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1072 - mae: 0.2456 - val_loss: 0.1227 - val_mae: 0.2664
# Epoch 28/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1063 - mae: 0.2442 - val_loss: 0.1207 - val_mae: 0.2600
# Epoch 29/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1031 - mae: 0.2373 - val_loss: 0.1194 - val_mae: 0.2605
# Epoch 30/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1023 - mae: 0.2373 - val_loss: 0.1179 - val_mae: 0.2550
# Epoch 31/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0967 - mae: 0.2305 - val_loss: 0.1167 - val_mae: 0.2576
# Epoch 32/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1046 - mae: 0.2352 - val_loss: 0.1163 - val_mae: 0.2589
# Epoch 33/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0910 - mae: 0.2233 - val_loss: 0.1136 - val_mae: 0.2492
# Epoch 34/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0955 - mae: 0.2274 - val_loss: 0.1122 - val_mae: 0.2507
# Epoch 35/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1049 - mae: 0.2403 - val_loss: 0.1116 - val_mae: 0.2514
# Epoch 36/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0971 - mae: 0.2313 - val_loss: 0.1088 - val_mae: 0.2441
# Epoch 37/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0856 - mae: 0.2144 - val_loss: 0.1081 - val_mae: 0.2460
# Epoch 38/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0916 - mae: 0.2190 - val_loss: 0.1060 - val_mae: 0.2403
# Epoch 39/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0933 - mae: 0.2276 - val_loss: 0.1044 - val_mae: 0.2379
# Epoch 40/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1033 - mae: 0.2368 - val_loss: 0.1038 - val_mae: 0.2393
# Epoch 41/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0861 - mae: 0.2153 - val_loss: 0.1017 - val_mae: 0.2318
# Epoch 42/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0873 - mae: 0.2122 - val_loss: 0.1002 - val_mae: 0.2329
# Epoch 43/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0934 - mae: 0.2216 - val_loss: 0.0986 - val_mae: 0.2315
# Epoch 44/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0818 - mae: 0.2026 - val_loss: 0.0975 - val_mae: 0.2288
# Epoch 45/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0876 - mae: 0.2107 - val_loss: 0.0961 - val_mae: 0.2261
# Epoch 46/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0806 - mae: 0.2020 - val_loss: 0.0997 - val_mae: 0.2390
# Epoch 47/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0790 - mae: 0.2082 - val_loss: 0.0949 - val_mae: 0.2305
# Epoch 48/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0788 - mae: 0.2063 - val_loss: 0.0923 - val_mae: 0.2262
# Epoch 49/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0754 - mae: 0.1975 - val_loss: 0.0891 - val_mae: 0.2184
# Epoch 50/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0862 - mae: 0.2097 - val_loss: 0.0874 - val_mae: 0.2120
# Epoch 51/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0740 - mae: 0.1952 - val_loss: 0.0869 - val_mae: 0.2182
# Epoch 52/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0714 - mae: 0.1973 - val_loss: 0.0845 - val_mae: 0.2129
# Epoch 53/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0747 - mae: 0.1966 - val_loss: 0.0832 - val_mae: 0.2104
# Epoch 54/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0727 - mae: 0.1927 - val_loss: 0.0820 - val_mae: 0.2078
# Epoch 55/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0665 - mae: 0.1872 - val_loss: 0.0812 - val_mae: 0.2096
# Epoch 56/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0686 - mae: 0.1880 - val_loss: 0.0800 - val_mae: 0.2006
# Epoch 57/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0625 - mae: 0.1737 - val_loss: 0.0786 - val_mae: 0.2028
# Epoch 58/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0663 - mae: 0.1852 - val_loss: 0.0781 - val_mae: 0.2037
# Epoch 59/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0676 - mae: 0.1854 - val_loss: 0.0768 - val_mae: 0.2006
# Epoch 60/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0661 - mae: 0.1818 - val_loss: 0.0753 - val_mae: 0.2004
# Epoch 61/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0620 - mae: 0.1721 - val_loss: 0.0744 - val_mae: 0.1929
# Epoch 62/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0624 - mae: 0.1801 - val_loss: 0.0732 - val_mae: 0.1992
# Epoch 63/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0624 - mae: 0.1782 - val_loss: 0.0723 - val_mae: 0.1956
# Epoch 64/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0590 - mae: 0.1739 - val_loss: 0.0702 - val_mae: 0.1905
# Epoch 65/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0552 - mae: 0.1712 - val_loss: 0.0700 - val_mae: 0.1961
# Epoch 66/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0569 - mae: 0.1711 - val_loss: 0.0694 - val_mae: 0.1880
# Epoch 67/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0597 - mae: 0.1726 - val_loss: 0.0671 - val_mae: 0.1897
# Epoch 68/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0573 - mae: 0.1693 - val_loss: 0.0657 - val_mae: 0.1838
# Epoch 69/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0538 - mae: 0.1616 - val_loss: 0.0643 - val_mae: 0.1845
# Epoch 70/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0539 - mae: 0.1663 - val_loss: 0.0633 - val_mae: 0.1843
# Epoch 71/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0537 - mae: 0.1629 - val_loss: 0.0624 - val_mae: 0.1807
# Epoch 72/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0546 - mae: 0.1627 - val_loss: 0.0609 - val_mae: 0.1787
# Epoch 73/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0600 - mae: 0.1736 - val_loss: 0.0594 - val_mae: 0.1760
# Epoch 74/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0496 - mae: 0.1615 - val_loss: 0.0586 - val_mae: 0.1783
# Epoch 75/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0527 - mae: 0.1636 - val_loss: 0.0570 - val_mae: 0.1753
# Epoch 76/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0470 - mae: 0.1531 - val_loss: 0.0559 - val_mae: 0.1713
# Epoch 77/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0486 - mae: 0.1581 - val_loss: 0.0550 - val_mae: 0.1726
# Epoch 78/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0448 - mae: 0.1495 - val_loss: 0.0539 - val_mae: 0.1654
# Epoch 79/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0448 - mae: 0.1496 - val_loss: 0.0523 - val_mae: 0.1699
# Epoch 80/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0406 - mae: 0.1464 - val_loss: 0.0509 - val_mae: 0.1645
# Epoch 81/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0433 - mae: 0.1483 - val_loss: 0.0496 - val_mae: 0.1629
# Epoch 82/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0439 - mae: 0.1482 - val_loss: 0.0484 - val_mae: 0.1610
# Epoch 83/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0391 - mae: 0.1390 - val_loss: 0.0472 - val_mae: 0.1613
# Epoch 84/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0401 - mae: 0.1434 - val_loss: 0.0462 - val_mae: 0.1558
# Epoch 85/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0438 - mae: 0.1489 - val_loss: 0.0446 - val_mae: 0.1562
# Epoch 86/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0338 - mae: 0.1317 - val_loss: 0.0438 - val_mae: 0.1562
# Epoch 87/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0353 - mae: 0.1354 - val_loss: 0.0438 - val_mae: 0.1589
# Epoch 88/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0368 - mae: 0.1406 - val_loss: 0.0412 - val_mae: 0.1513
# Epoch 89/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0357 - mae: 0.1374 - val_loss: 0.0404 - val_mae: 0.1505
# Epoch 90/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0336 - mae: 0.1325 - val_loss: 0.0391 - val_mae: 0.1488
# Epoch 91/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0348 - mae: 0.1366 - val_loss: 0.0387 - val_mae: 0.1433
# Epoch 92/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0347 - mae: 0.1327 - val_loss: 0.0375 - val_mae: 0.1450
# Epoch 93/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0300 - mae: 0.1275 - val_loss: 0.0357 - val_mae: 0.1418
# Epoch 94/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0324 - mae: 0.1300 - val_loss: 0.0348 - val_mae: 0.1411
# Epoch 95/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0313 - mae: 0.1276 - val_loss: 0.0342 - val_mae: 0.1359
# Epoch 96/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0294 - mae: 0.1244 - val_loss: 0.0324 - val_mae: 0.1364
# Epoch 97/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0307 - mae: 0.1275 - val_loss: 0.0319 - val_mae: 0.1334
# Epoch 98/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0280 - mae: 0.1222 - val_loss: 0.0307 - val_mae: 0.1339
# Epoch 99/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0281 - mae: 0.1221 - val_loss: 0.0295 - val_mae: 0.1304
# Epoch 100/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0281 - mae: 0.1229 - val_loss: 0.0294 - val_mae: 0.1272
# Epoch 101/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0257 - mae: 0.1164 - val_loss: 0.0280 - val_mae: 0.1293
# Epoch 102/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0258 - mae: 0.1176 - val_loss: 0.0277 - val_mae: 0.1284
# Epoch 103/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0233 - mae: 0.1132 - val_loss: 0.0288 - val_mae: 0.1243
# Epoch 104/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0268 - mae: 0.1182 - val_loss: 0.0263 - val_mae: 0.1273
# Epoch 105/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0252 - mae: 0.1184 - val_loss: 0.0260 - val_mae: 0.1267
# Epoch 106/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0234 - mae: 0.1136 - val_loss: 0.0243 - val_mae: 0.1217
# Epoch 107/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0224 - mae: 0.1108 - val_loss: 0.0235 - val_mae: 0.1203
# Epoch 108/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0251 - mae: 0.1181 - val_loss: 0.0256 - val_mae: 0.1175
# Epoch 109/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0237 - mae: 0.1147 - val_loss: 0.0223 - val_mae: 0.1172
# Epoch 110/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0208 - mae: 0.1063 - val_loss: 0.0217 - val_mae: 0.1164
# Epoch 111/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0203 - mae: 0.1082 - val_loss: 0.0218 - val_mae: 0.1142
# Epoch 112/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0216 - mae: 0.1068 - val_loss: 0.0218 - val_mae: 0.1148
# Epoch 113/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0226 - mae: 0.1106 - val_loss: 0.0200 - val_mae: 0.1125
# Epoch 114/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0195 - mae: 0.1063 - val_loss: 0.0198 - val_mae: 0.1118
# Epoch 115/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0184 - mae: 0.1038 - val_loss: 0.0198 - val_mae: 0.1099
# Epoch 116/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0180 - mae: 0.1031 - val_loss: 0.0190 - val_mae: 0.1094
# Epoch 117/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0179 - mae: 0.1018 - val_loss: 0.0193 - val_mae: 0.1091
# Epoch 118/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0188 - mae: 0.1029 - val_loss: 0.0185 - val_mae: 0.1085
# Epoch 119/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0173 - mae: 0.1005 - val_loss: 0.0175 - val_mae: 0.1062
# Epoch 120/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0158 - mae: 0.0967 - val_loss: 0.0182 - val_mae: 0.1080
# Epoch 121/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0162 - mae: 0.0990 - val_loss: 0.0181 - val_mae: 0.1076
# Epoch 122/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0181 - mae: 0.1045 - val_loss: 0.0181 - val_mae: 0.1067
# Epoch 123/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0174 - mae: 0.1030 - val_loss: 0.0168 - val_mae: 0.1034
# Epoch 124/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0153 - mae: 0.0959 - val_loss: 0.0161 - val_mae: 0.1032
# Epoch 125/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0149 - mae: 0.0948 - val_loss: 0.0161 - val_mae: 0.1023
# Epoch 126/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0156 - mae: 0.0975 - val_loss: 0.0158 - val_mae: 0.1007
# Epoch 127/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0152 - mae: 0.0959 - val_loss: 0.0152 - val_mae: 0.1005
# Epoch 128/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0161 - mae: 0.1008 - val_loss: 0.0153 - val_mae: 0.1006
# Epoch 129/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0149 - mae: 0.0957 - val_loss: 0.0165 - val_mae: 0.1002
# Epoch 130/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0150 - mae: 0.0969 - val_loss: 0.0148 - val_mae: 0.0977
# Epoch 131/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0153 - mae: 0.0957 - val_loss: 0.0153 - val_mae: 0.0979
# Epoch 132/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0155 - mae: 0.0971 - val_loss: 0.0143 - val_mae: 0.0977
# Epoch 133/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0149 - mae: 0.0958 - val_loss: 0.0149 - val_mae: 0.0965
# Epoch 134/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0144 - mae: 0.0938 - val_loss: 0.0139 - val_mae: 0.0954
# Epoch 135/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0134 - mae: 0.0917 - val_loss: 0.0149 - val_mae: 0.0969
# Epoch 136/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0127 - mae: 0.0898 - val_loss: 0.0135 - val_mae: 0.0934
# Epoch 137/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0149 - mae: 0.0957 - val_loss: 0.0150 - val_mae: 0.0966
# Epoch 138/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0155 - mae: 0.0973 - val_loss: 0.0131 - val_mae: 0.0928
# Epoch 139/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0146 - mae: 0.0952 - val_loss: 0.0156 - val_mae: 0.0972
# Epoch 140/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0138 - mae: 0.0915 - val_loss: 0.0128 - val_mae: 0.0914
# Epoch 141/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0138 - mae: 0.0931 - val_loss: 0.0141 - val_mae: 0.0939
# Epoch 142/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0150 - mae: 0.0960 - val_loss: 0.0126 - val_mae: 0.0906
# Epoch 143/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0131 - mae: 0.0896 - val_loss: 0.0133 - val_mae: 0.0923
# Epoch 144/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0130 - mae: 0.0916 - val_loss: 0.0127 - val_mae: 0.0898
# Epoch 145/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0137 - mae: 0.0950 - val_loss: 0.0128 - val_mae: 0.0905
# Epoch 146/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0124 - mae: 0.0895 - val_loss: 0.0125 - val_mae: 0.0908
# Epoch 147/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0128 - mae: 0.0889 - val_loss: 0.0133 - val_mae: 0.0927
# Epoch 148/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0127 - mae: 0.0882 - val_loss: 0.0123 - val_mae: 0.0895
# Epoch 149/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0120 - mae: 0.0872 - val_loss: 0.0129 - val_mae: 0.0912
# Epoch 150/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0131 - mae: 0.0907 - val_loss: 0.0123 - val_mae: 0.0892
# Epoch 151/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0134 - mae: 0.0920 - val_loss: 0.0125 - val_mae: 0.0897
# Epoch 152/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0131 - mae: 0.0907 - val_loss: 0.0122 - val_mae: 0.0895
# Epoch 153/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0122 - mae: 0.0888 - val_loss: 0.0137 - val_mae: 0.0944
# Epoch 154/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0137 - mae: 0.0925 - val_loss: 0.0142 - val_mae: 0.0957
# Epoch 155/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0132 - mae: 0.0905 - val_loss: 0.0117 - val_mae: 0.0870
# Epoch 156/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0137 - mae: 0.0919 - val_loss: 0.0134 - val_mae: 0.0917
# Epoch 157/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0137 - mae: 0.0936 - val_loss: 0.0126 - val_mae: 0.0890
# Epoch 158/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0124 - mae: 0.0897 - val_loss: 0.0118 - val_mae: 0.0866
# Epoch 159/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0132 - mae: 0.0914 - val_loss: 0.0121 - val_mae: 0.0895
# Epoch 160/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0125 - mae: 0.0895 - val_loss: 0.0120 - val_mae: 0.0883
# Epoch 161/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0123 - mae: 0.0876 - val_loss: 0.0122 - val_mae: 0.0876
# Epoch 162/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0111 - mae: 0.0845 - val_loss: 0.0118 - val_mae: 0.0879
# Epoch 163/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0115 - mae: 0.0866 - val_loss: 0.0131 - val_mae: 0.0910
# Epoch 164/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0125 - mae: 0.0886 - val_loss: 0.0119 - val_mae: 0.0886
# Epoch 165/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0117 - mae: 0.0884 - val_loss: 0.0122 - val_mae: 0.0894
# Epoch 166/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0132 - mae: 0.0905 - val_loss: 0.0124 - val_mae: 0.0888
# Epoch 167/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0117 - mae: 0.0870 - val_loss: 0.0119 - val_mae: 0.0882
# Epoch 168/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0132 - mae: 0.0930 - val_loss: 0.0116 - val_mae: 0.0872
# Epoch 169/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0123 - mae: 0.0895 - val_loss: 0.0131 - val_mae: 0.0909
# Epoch 170/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0124 - mae: 0.0897 - val_loss: 0.0115 - val_mae: 0.0872
# Epoch 171/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0128 - mae: 0.0907 - val_loss: 0.0122 - val_mae: 0.0892
# Epoch 172/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - mae: 0.0955 - val_loss: 0.0121 - val_mae: 0.0891
# Epoch 173/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0118 - mae: 0.0874 - val_loss: 0.0113 - val_mae: 0.0852
# Epoch 174/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0124 - mae: 0.0895 - val_loss: 0.0127 - val_mae: 0.0897
# Epoch 175/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0121 - mae: 0.0884 - val_loss: 0.0115 - val_mae: 0.0860
# Epoch 176/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0114 - mae: 0.0864 - val_loss: 0.0116 - val_mae: 0.0872
# Epoch 177/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0113 - mae: 0.0848 - val_loss: 0.0113 - val_mae: 0.0863
# Epoch 178/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0123 - mae: 0.0883 - val_loss: 0.0113 - val_mae: 0.0861
# Epoch 179/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0128 - mae: 0.0904 - val_loss: 0.0115 - val_mae: 0.0860
# Epoch 180/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0114 - mae: 0.0853 - val_loss: 0.0113 - val_mae: 0.0867
# Epoch 181/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0121 - mae: 0.0868 - val_loss: 0.0116 - val_mae: 0.0870
# Epoch 182/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0119 - mae: 0.0876 - val_loss: 0.0116 - val_mae: 0.0876
# Epoch 183/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0111 - mae: 0.0835 - val_loss: 0.0115 - val_mae: 0.0871
# Epoch 184/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0121 - mae: 0.0878 - val_loss: 0.0116 - val_mae: 0.0870
# Epoch 185/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0116 - mae: 0.0860 - val_loss: 0.0117 - val_mae: 0.0870
# Epoch 186/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0121 - mae: 0.0877 - val_loss: 0.0117 - val_mae: 0.0875
# Epoch 187/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0125 - mae: 0.0897 - val_loss: 0.0116 - val_mae: 0.0871
# Epoch 188/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0119 - mae: 0.0897 - val_loss: 0.0112 - val_mae: 0.0858
# Epoch 189/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0124 - mae: 0.0889 - val_loss: 0.0111 - val_mae: 0.0852
# Epoch 190/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0123 - mae: 0.0891 - val_loss: 0.0131 - val_mae: 0.0913
# Epoch 191/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0125 - mae: 0.0937 - val_loss: 0.0124 - val_mae: 0.0890
# Epoch 192/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0128 - mae: 0.0903 - val_loss: 0.0122 - val_mae: 0.0879
# Epoch 193/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0129 - mae: 0.0907 - val_loss: 0.0110 - val_mae: 0.0850
# Epoch 194/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0125 - mae: 0.0892 - val_loss: 0.0118 - val_mae: 0.0876
# Epoch 195/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - mae: 0.0937 - val_loss: 0.0119 - val_mae: 0.0866
# Epoch 196/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0124 - mae: 0.0896 - val_loss: 0.0112 - val_mae: 0.0850
# Epoch 197/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0111 - mae: 0.0841 - val_loss: 0.0112 - val_mae: 0.0858
# Epoch 198/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0115 - mae: 0.0867 - val_loss: 0.0119 - val_mae: 0.0884
# Epoch 199/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0128 - mae: 0.0902 - val_loss: 0.0114 - val_mae: 0.0863
# Epoch 200/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0116 - mae: 0.0856 - val_loss: 0.0112 - val_mae: 0.0854
# Epoch 201/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0125 - mae: 0.0912 - val_loss: 0.0116 - val_mae: 0.0864
# Epoch 202/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0111 - mae: 0.0849 - val_loss: 0.0115 - val_mae: 0.0861
# Epoch 203/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0120 - mae: 0.0876 - val_loss: 0.0116 - val_mae: 0.0876
# Epoch 204/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0128 - mae: 0.0902 - val_loss: 0.0111 - val_mae: 0.0850
# Epoch 205/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0120 - mae: 0.0881 - val_loss: 0.0111 - val_mae: 0.0846
# Epoch 206/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0112 - mae: 0.0841 - val_loss: 0.0114 - val_mae: 0.0860
# Epoch 207/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0129 - mae: 0.0911 - val_loss: 0.0112 - val_mae: 0.0860
# Epoch 208/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0128 - mae: 0.0917 - val_loss: 0.0112 - val_mae: 0.0856
# Epoch 209/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0117 - mae: 0.0870 - val_loss: 0.0113 - val_mae: 0.0862
# Epoch 210/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0112 - mae: 0.0851 - val_loss: 0.0126 - val_mae: 0.0910
# Epoch 211/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0119 - mae: 0.0876 - val_loss: 0.0110 - val_mae: 0.0848
# Epoch 212/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0113 - mae: 0.0851 - val_loss: 0.0120 - val_mae: 0.0882
# Epoch 213/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0131 - mae: 0.0934 - val_loss: 0.0115 - val_mae: 0.0868
# Epoch 214/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0130 - mae: 0.0912 - val_loss: 0.0118 - val_mae: 0.0876
# Epoch 215/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0129 - mae: 0.0911 - val_loss: 0.0116 - val_mae: 0.0855
# Epoch 216/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0117 - mae: 0.0880 - val_loss: 0.0113 - val_mae: 0.0850
# Epoch 217/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0120 - mae: 0.0886 - val_loss: 0.0117 - val_mae: 0.0879
# Epoch 218/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0115 - mae: 0.0861 - val_loss: 0.0114 - val_mae: 0.0853
# Epoch 219/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0113 - mae: 0.0857 - val_loss: 0.0115 - val_mae: 0.0853
# Epoch 220/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0121 - mae: 0.0869 - val_loss: 0.0112 - val_mae: 0.0861
# Epoch 221/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0120 - mae: 0.0866 - val_loss: 0.0111 - val_mae: 0.0856
# Epoch 222/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0142 - mae: 0.0969 - val_loss: 0.0113 - val_mae: 0.0866
# Epoch 223/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0129 - mae: 0.0904 - val_loss: 0.0111 - val_mae: 0.0843
# Epoch 224/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0124 - mae: 0.0883 - val_loss: 0.0109 - val_mae: 0.0842
# Epoch 225/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0122 - mae: 0.0893 - val_loss: 0.0114 - val_mae: 0.0861
# Epoch 226/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0125 - mae: 0.0890 - val_loss: 0.0109 - val_mae: 0.0846
# Epoch 227/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0114 - mae: 0.0857 - val_loss: 0.0116 - val_mae: 0.0869
# Epoch 228/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0126 - mae: 0.0905 - val_loss: 0.0138 - val_mae: 0.0939
# Epoch 229/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0127 - mae: 0.0909 - val_loss: 0.0118 - val_mae: 0.0885
# Epoch 230/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0119 - mae: 0.0869 - val_loss: 0.0108 - val_mae: 0.0839
# Epoch 231/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0118 - mae: 0.0869 - val_loss: 0.0114 - val_mae: 0.0862
# Epoch 232/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0126 - mae: 0.0901 - val_loss: 0.0108 - val_mae: 0.0842
# Epoch 233/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0117 - mae: 0.0880 - val_loss: 0.0122 - val_mae: 0.0894
# Epoch 234/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0122 - mae: 0.0870 - val_loss: 0.0140 - val_mae: 0.0950
# Epoch 235/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0135 - mae: 0.0927 - val_loss: 0.0119 - val_mae: 0.0882
# Epoch 236/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0120 - mae: 0.0874 - val_loss: 0.0122 - val_mae: 0.0892
# Epoch 237/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0128 - mae: 0.0891 - val_loss: 0.0130 - val_mae: 0.0916
# Epoch 238/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0118 - mae: 0.0862 - val_loss: 0.0121 - val_mae: 0.0888
# Epoch 239/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0124 - mae: 0.0896 - val_loss: 0.0107 - val_mae: 0.0844
# Epoch 240/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0114 - mae: 0.0853 - val_loss: 0.0119 - val_mae: 0.0859
# Epoch 241/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0120 - mae: 0.0871 - val_loss: 0.0108 - val_mae: 0.0836
# Epoch 242/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0121 - mae: 0.0891 - val_loss: 0.0111 - val_mae: 0.0865
# Epoch 243/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0119 - mae: 0.0874 - val_loss: 0.0106 - val_mae: 0.0844
# Epoch 244/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0136 - mae: 0.0920 - val_loss: 0.0110 - val_mae: 0.0838
# Epoch 245/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0124 - mae: 0.0898 - val_loss: 0.0112 - val_mae: 0.0860
# Epoch 246/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0120 - mae: 0.0877 - val_loss: 0.0115 - val_mae: 0.0863
# Epoch 247/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0127 - mae: 0.0902 - val_loss: 0.0110 - val_mae: 0.0848
# Epoch 248/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0117 - mae: 0.0863 - val_loss: 0.0107 - val_mae: 0.0840
# Epoch 249/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0116 - mae: 0.0875 - val_loss: 0.0113 - val_mae: 0.0844
# Epoch 250/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0116 - mae: 0.0864 - val_loss: 0.0109 - val_mae: 0.0849
# Epoch 251/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0117 - mae: 0.0854 - val_loss: 0.0109 - val_mae: 0.0847
# Epoch 252/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0119 - mae: 0.0858 - val_loss: 0.0114 - val_mae: 0.0858
# Epoch 253/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0115 - mae: 0.0865 - val_loss: 0.0106 - val_mae: 0.0834
# Epoch 254/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0116 - mae: 0.0871 - val_loss: 0.0112 - val_mae: 0.0864
# Epoch 255/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0115 - mae: 0.0846 - val_loss: 0.0106 - val_mae: 0.0845
# Epoch 256/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0113 - mae: 0.0863 - val_loss: 0.0108 - val_mae: 0.0840
# Epoch 257/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0111 - mae: 0.0846 - val_loss: 0.0107 - val_mae: 0.0849
# Epoch 258/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0125 - mae: 0.0912 - val_loss: 0.0130 - val_mae: 0.0907
# Epoch 259/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0140 - mae: 0.0932 - val_loss: 0.0135 - val_mae: 0.0929
# Epoch 260/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0139 - mae: 0.0955 - val_loss: 0.0119 - val_mae: 0.0882
# Epoch 261/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0124 - mae: 0.0880 - val_loss: 0.0116 - val_mae: 0.0853
# Epoch 262/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0124 - mae: 0.0901 - val_loss: 0.0108 - val_mae: 0.0855
# Epoch 263/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0122 - mae: 0.0886 - val_loss: 0.0107 - val_mae: 0.0844
# Epoch 264/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0110 - mae: 0.0841 - val_loss: 0.0107 - val_mae: 0.0839
# Epoch 265/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0112 - mae: 0.0851 - val_loss: 0.0114 - val_mae: 0.0849
# Epoch 266/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0113 - mae: 0.0856 - val_loss: 0.0121 - val_mae: 0.0885
# Epoch 267/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0113 - mae: 0.0841 - val_loss: 0.0107 - val_mae: 0.0837
# Epoch 268/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0115 - mae: 0.0842 - val_loss: 0.0115 - val_mae: 0.0856
# Epoch 269/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0118 - mae: 0.0883 - val_loss: 0.0106 - val_mae: 0.0844
# Epoch 270/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0116 - mae: 0.0868 - val_loss: 0.0107 - val_mae: 0.0842
# Epoch 271/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0116 - mae: 0.0846 - val_loss: 0.0123 - val_mae: 0.0874
# Epoch 272/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0113 - mae: 0.0840 - val_loss: 0.0109 - val_mae: 0.0845
# Epoch 273/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0114 - mae: 0.0869 - val_loss: 0.0108 - val_mae: 0.0840
# Epoch 274/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0117 - mae: 0.0872 - val_loss: 0.0108 - val_mae: 0.0841
# Epoch 275/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0115 - mae: 0.0869 - val_loss: 0.0116 - val_mae: 0.0851
# Epoch 276/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0115 - mae: 0.0863 - val_loss: 0.0111 - val_mae: 0.0839
# Epoch 277/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0114 - mae: 0.0857 - val_loss: 0.0119 - val_mae: 0.0884
# Epoch 278/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0112 - mae: 0.0858 - val_loss: 0.0113 - val_mae: 0.0852
# Epoch 279/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0124 - mae: 0.0893 - val_loss: 0.0127 - val_mae: 0.0906
# Epoch 280/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0127 - mae: 0.0902 - val_loss: 0.0106 - val_mae: 0.0835
# Epoch 281/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0111 - mae: 0.0855 - val_loss: 0.0106 - val_mae: 0.0832
# Epoch 282/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0104 - mae: 0.0824 - val_loss: 0.0105 - val_mae: 0.0837
# Epoch 283/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0118 - mae: 0.0868 - val_loss: 0.0115 - val_mae: 0.0871
# Epoch 284/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0124 - mae: 0.0884 - val_loss: 0.0119 - val_mae: 0.0872
# Epoch 285/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0132 - mae: 0.0910 - val_loss: 0.0109 - val_mae: 0.0857
# Epoch 286/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0113 - mae: 0.0861 - val_loss: 0.0110 - val_mae: 0.0838
# Epoch 287/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0115 - mae: 0.0868 - val_loss: 0.0108 - val_mae: 0.0840
# Epoch 288/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0118 - mae: 0.0862 - val_loss: 0.0121 - val_mae: 0.0872
# Epoch 289/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0119 - mae: 0.0885 - val_loss: 0.0110 - val_mae: 0.0848
# Epoch 290/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0125 - mae: 0.0911 - val_loss: 0.0106 - val_mae: 0.0844
# Epoch 291/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0115 - mae: 0.0864 - val_loss: 0.0121 - val_mae: 0.0870
# Epoch 292/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0124 - mae: 0.0894 - val_loss: 0.0108 - val_mae: 0.0840
# Epoch 293/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0115 - mae: 0.0864 - val_loss: 0.0107 - val_mae: 0.0841
# Epoch 294/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0112 - mae: 0.0862 - val_loss: 0.0114 - val_mae: 0.0855
# Epoch 295/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0118 - mae: 0.0869 - val_loss: 0.0113 - val_mae: 0.0850
# Epoch 296/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0115 - mae: 0.0849 - val_loss: 0.0117 - val_mae: 0.0854
# Epoch 297/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0121 - mae: 0.0888 - val_loss: 0.0108 - val_mae: 0.0843
# Epoch 298/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0118 - mae: 0.0885 - val_loss: 0.0131 - val_mae: 0.0893
# Epoch 299/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0128 - mae: 0.0923 - val_loss: 0.0118 - val_mae: 0.0864
# Epoch 300/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0126 - mae: 0.0906 - val_loss: 0.0131 - val_mae: 0.0912
# Epoch 301/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0134 - mae: 0.0935 - val_loss: 0.0130 - val_mae: 0.0910
# Epoch 302/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0122 - mae: 0.0886 - val_loss: 0.0109 - val_mae: 0.0843
# Epoch 303/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0115 - mae: 0.0873 - val_loss: 0.0125 - val_mae: 0.0894
# Epoch 304/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0125 - mae: 0.0900 - val_loss: 0.0131 - val_mae: 0.0917
# Epoch 305/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0123 - mae: 0.0896 - val_loss: 0.0178 - val_mae: 0.1064
# Epoch 306/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0144 - mae: 0.0961 - val_loss: 0.0117 - val_mae: 0.0868
# Epoch 307/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0116 - mae: 0.0865 - val_loss: 0.0110 - val_mae: 0.0866
# Epoch 308/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0114 - mae: 0.0876 - val_loss: 0.0112 - val_mae: 0.0850
# Epoch 309/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0113 - mae: 0.0843 - val_loss: 0.0115 - val_mae: 0.0855
# Epoch 310/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0131 - mae: 0.0924 - val_loss: 0.0109 - val_mae: 0.0849
# Epoch 311/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0123 - mae: 0.0885 - val_loss: 0.0113 - val_mae: 0.0858
# Epoch 312/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0109 - mae: 0.0845 - val_loss: 0.0110 - val_mae: 0.0853
# Epoch 313/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0122 - mae: 0.0908 - val_loss: 0.0111 - val_mae: 0.0868
# Epoch 314/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0125 - mae: 0.0881 - val_loss: 0.0130 - val_mae: 0.0887
# Epoch 315/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0119 - mae: 0.0869 - val_loss: 0.0110 - val_mae: 0.0840
# Epoch 316/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0116 - mae: 0.0875 - val_loss: 0.0112 - val_mae: 0.0847
# Epoch 317/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0116 - mae: 0.0867 - val_loss: 0.0107 - val_mae: 0.0849
# Epoch 318/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0115 - mae: 0.0864 - val_loss: 0.0108 - val_mae: 0.0845
# Epoch 319/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0110 - mae: 0.0847 - val_loss: 0.0120 - val_mae: 0.0861
# Epoch 320/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0112 - mae: 0.0865 - val_loss: 0.0114 - val_mae: 0.0879
# Epoch 321/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0116 - mae: 0.0860 - val_loss: 0.0112 - val_mae: 0.0852
# Epoch 322/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0109 - mae: 0.0850 - val_loss: 0.0111 - val_mae: 0.0843
# Epoch 323/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0114 - mae: 0.0861 - val_loss: 0.0109 - val_mae: 0.0846
# Epoch 324/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0113 - mae: 0.0866 - val_loss: 0.0109 - val_mae: 0.0853
# Epoch 325/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0121 - mae: 0.0884 - val_loss: 0.0108 - val_mae: 0.0856
# Epoch 326/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0123 - mae: 0.0897 - val_loss: 0.0109 - val_mae: 0.0854
# Epoch 327/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0111 - mae: 0.0854 - val_loss: 0.0112 - val_mae: 0.0862
# Epoch 328/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0116 - mae: 0.0860 - val_loss: 0.0110 - val_mae: 0.0843
# Epoch 329/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0114 - mae: 0.0866 - val_loss: 0.0118 - val_mae: 0.0864
# Epoch 330/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0118 - mae: 0.0869 - val_loss: 0.0122 - val_mae: 0.0872
# Epoch 331/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0123 - mae: 0.0897 - val_loss: 0.0108 - val_mae: 0.0854
# Epoch 332/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0113 - mae: 0.0857 - val_loss: 0.0110 - val_mae: 0.0852
# Epoch 333/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0116 - mae: 0.0862 - val_loss: 0.0107 - val_mae: 0.0848
# Epoch 334/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0121 - mae: 0.0890 - val_loss: 0.0108 - val_mae: 0.0848
# Epoch 335/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0108 - mae: 0.0832 - val_loss: 0.0119 - val_mae: 0.0872
# Epoch 336/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0117 - mae: 0.0869 - val_loss: 0.0108 - val_mae: 0.0854
# Epoch 337/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0114 - mae: 0.0865 - val_loss: 0.0109 - val_mae: 0.0849
# Epoch 338/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0109 - mae: 0.0844 - val_loss: 0.0120 - val_mae: 0.0862
# Epoch 339/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0116 - mae: 0.0873 - val_loss: 0.0111 - val_mae: 0.0857
# Epoch 340/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0104 - mae: 0.0836 - val_loss: 0.0108 - val_mae: 0.0844
# Epoch 341/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0113 - mae: 0.0852 - val_loss: 0.0108 - val_mae: 0.0847
# Epoch 342/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0116 - mae: 0.0870 - val_loss: 0.0121 - val_mae: 0.0876
# Epoch 343/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0133 - mae: 0.0928 - val_loss: 0.0123 - val_mae: 0.0874
# Epoch 344/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0117 - mae: 0.0863 - val_loss: 0.0109 - val_mae: 0.0856
# Epoch 345/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0111 - mae: 0.0848 - val_loss: 0.0108 - val_mae: 0.0845
# Epoch 346/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0116 - mae: 0.0871 - val_loss: 0.0120 - val_mae: 0.0874
# Epoch 347/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0107 - mae: 0.0830 - val_loss: 0.0121 - val_mae: 0.0879
# Epoch 348/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0129 - mae: 0.0910 - val_loss: 0.0119 - val_mae: 0.0887
# Epoch 349/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0118 - mae: 0.0888 - val_loss: 0.0113 - val_mae: 0.0859
# Epoch 350/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0116 - mae: 0.0858 - val_loss: 0.0136 - val_mae: 0.0937
# Epoch 351/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0136 - mae: 0.0927 - val_loss: 0.0126 - val_mae: 0.0899
# Epoch 352/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0118 - mae: 0.0868 - val_loss: 0.0111 - val_mae: 0.0864
# Epoch 353/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0116 - mae: 0.0877 - val_loss: 0.0109 - val_mae: 0.0848
# Epoch 354/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0111 - mae: 0.0857 - val_loss: 0.0115 - val_mae: 0.0858
# Epoch 355/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0107 - mae: 0.0838 - val_loss: 0.0112 - val_mae: 0.0863
# Epoch 356/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0117 - mae: 0.0874 - val_loss: 0.0124 - val_mae: 0.0889
# Epoch 357/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0129 - mae: 0.0932 - val_loss: 0.0118 - val_mae: 0.0869
# Epoch 358/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0117 - mae: 0.0874 - val_loss: 0.0112 - val_mae: 0.0857
# Epoch 359/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0108 - mae: 0.0846 - val_loss: 0.0113 - val_mae: 0.0876
# Epoch 360/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0125 - mae: 0.0907 - val_loss: 0.0116 - val_mae: 0.0882
# Epoch 361/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0129 - mae: 0.0918 - val_loss: 0.0123 - val_mae: 0.0879
# Epoch 362/500
# ...
# Epoch 381/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0111 - mae: 0.0864 - val_loss: 0.0109 - val_mae: 0.0857
# Epoch 382/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0116 - mae: 0.0869 - val_loss: 0.0119 - val_mae: 0.0873
# Epoch 383/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0110 - mae: 0.0852 - val_loss: 0.0121 - val_mae: 0.0882
# Epoch 384/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0120 - mae: 0.0881 - val_loss: 0.0116 - val_mae: 0.0870
# Epoch 385/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0119 - mae: 0.0888 - val_loss: 0.0114 - val_mae: 0.0873
# Epoch 386/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0107 - mae: 0.0830 - val_loss: 0.0111 - val_mae: 0.0862
# Epoch 387/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0121 - mae: 0.0885 - val_loss: 0.0120 - val_mae: 0.0873
# Epoch 388/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0123 - mae: 0.0891 - val_loss: 0.0118 - val_mae: 0.0878
# Epoch 389/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0124 - mae: 0.0900 - val_loss: 0.0124 - val_mae: 0.0894
# Epoch 390/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0121 - mae: 0.0879 - val_loss: 0.0122 - val_mae: 0.0882
# Epoch 391/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0117 - mae: 0.0870 - val_loss: 0.0123 - val_mae: 0.0894
# Epoch 392/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0119 - mae: 0.0857 - val_loss: 0.0121 - val_mae: 0.0882
# Epoch 393/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0110 - mae: 0.0849 - val_loss: 0.0115 - val_mae: 0.0871
# Epoch 394/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0111 - mae: 0.0861 - val_loss: 0.0113 - val_mae: 0.0868
# Epoch 395/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0118 - mae: 0.0883 - val_loss: 0.0112 - val_mae: 0.0859
# Epoch 396/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0121 - mae: 0.0877 - val_loss: 0.0121 - val_mae: 0.0872
# Epoch 397/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0112 - mae: 0.0855 - val_loss: 0.0113 - val_mae: 0.0858
# Epoch 398/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0116 - mae: 0.0870 - val_loss: 0.0118 - val_mae: 0.0891
# Epoch 399/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0122 - mae: 0.0899 - val_loss: 0.0114 - val_mae: 0.0866
# Epoch 400/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0113 - mae: 0.0870 - val_loss: 0.0121 - val_mae: 0.0875
# Epoch 401/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0108 - mae: 0.0838 - val_loss: 0.0110 - val_mae: 0.0859
# Epoch 402/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0116 - mae: 0.0876 - val_loss: 0.0113 - val_mae: 0.0864
# Epoch 403/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0107 - mae: 0.0837 - val_loss: 0.0115 - val_mae: 0.0861
# Epoch 404/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0110 - mae: 0.0846 - val_loss: 0.0123 - val_mae: 0.0884
# Epoch 405/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0112 - mae: 0.0881 - val_loss: 0.0113 - val_mae: 0.0866
# Epoch 406/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0113 - mae: 0.0854 - val_loss: 0.0110 - val_mae: 0.0856
# Epoch 407/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0106 - mae: 0.0841 - val_loss: 0.0111 - val_mae: 0.0860
# Epoch 408/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0112 - mae: 0.0865 - val_loss: 0.0111 - val_mae: 0.0860
# Epoch 409/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0112 - mae: 0.0856 - val_loss: 0.0121 - val_mae: 0.0883
# Epoch 410/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0114 - mae: 0.0856 - val_loss: 0.0116 - val_mae: 0.0863
# Epoch 411/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0115 - mae: 0.0862 - val_loss: 0.0113 - val_mae: 0.0865
# Epoch 412/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0106 - mae: 0.0829 - val_loss: 0.0111 - val_mae: 0.0859
# Epoch 413/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0108 - mae: 0.0844 - val_loss: 0.0115 - val_mae: 0.0870
# Epoch 414/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0104 - mae: 0.0831 - val_loss: 0.0120 - val_mae: 0.0876
# Epoch 415/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0118 - mae: 0.0880 - val_loss: 0.0115 - val_mae: 0.0862
# Epoch 416/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0117 - mae: 0.0871 - val_loss: 0.0114 - val_mae: 0.0861
# Epoch 417/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0115 - mae: 0.0869 - val_loss: 0.0113 - val_mae: 0.0868
# Epoch 418/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0115 - mae: 0.0851 - val_loss: 0.0116 - val_mae: 0.0883
# Epoch 419/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0118 - mae: 0.0877 - val_loss: 0.0133 - val_mae: 0.0912
# Epoch 420/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0119 - mae: 0.0893 - val_loss: 0.0120 - val_mae: 0.0882
# Epoch 421/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0117 - mae: 0.0879 - val_loss: 0.0133 - val_mae: 0.0942
# Epoch 422/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0140 - mae: 0.0960 - val_loss: 0.0113 - val_mae: 0.0867
# Epoch 423/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0116 - mae: 0.0878 - val_loss: 0.0115 - val_mae: 0.0867
# Epoch 424/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0114 - mae: 0.0862 - val_loss: 0.0109 - val_mae: 0.0852
# Epoch 425/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0111 - mae: 0.0858 - val_loss: 0.0113 - val_mae: 0.0864
# Epoch 426/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0117 - mae: 0.0865 - val_loss: 0.0111 - val_mae: 0.0864
# Epoch 427/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0113 - mae: 0.0840 - val_loss: 0.0119 - val_mae: 0.0874
# Epoch 428/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0109 - mae: 0.0849 - val_loss: 0.0115 - val_mae: 0.0871
# Epoch 429/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0105 - mae: 0.0824 - val_loss: 0.0113 - val_mae: 0.0859
# Epoch 430/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0108 - mae: 0.0853 - val_loss: 0.0115 - val_mae: 0.0867
# Epoch 431/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0112 - mae: 0.0860 - val_loss: 0.0113 - val_mae: 0.0864
# Epoch 432/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0118 - mae: 0.0871 - val_loss: 0.0112 - val_mae: 0.0864
# Epoch 433/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0113 - mae: 0.0861 - val_loss: 0.0110 - val_mae: 0.0855
# Epoch 434/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0108 - mae: 0.0853 - val_loss: 0.0122 - val_mae: 0.0879
# Epoch 435/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0114 - mae: 0.0868 - val_loss: 0.0120 - val_mae: 0.0891
# Epoch 436/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0117 - mae: 0.0859 - val_loss: 0.0132 - val_mae: 0.0921
# Epoch 437/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0122 - mae: 0.0888 - val_loss: 0.0125 - val_mae: 0.0897
# Epoch 438/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0110 - mae: 0.0836 - val_loss: 0.0116 - val_mae: 0.0865
# Epoch 439/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0123 - mae: 0.0899 - val_loss: 0.0125 - val_mae: 0.0894
# Epoch 440/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0105 - mae: 0.0838 - val_loss: 0.0112 - val_mae: 0.0867
# Epoch 441/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0114 - mae: 0.0863 - val_loss: 0.0114 - val_mae: 0.0867
# Epoch 442/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0107 - mae: 0.0845 - val_loss: 0.0113 - val_mae: 0.0865
# Epoch 443/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0106 - mae: 0.0819 - val_loss: 0.0115 - val_mae: 0.0871
# Epoch 444/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0113 - mae: 0.0841 - val_loss: 0.0114 - val_mae: 0.0868
# Epoch 445/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0107 - mae: 0.0829 - val_loss: 0.0134 - val_mae: 0.0913
# Epoch 446/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0117 - mae: 0.0864 - val_loss: 0.0117 - val_mae: 0.0866
# Epoch 447/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0118 - mae: 0.0871 - val_loss: 0.0126 - val_mae: 0.0908
# Epoch 448/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0113 - mae: 0.0852 - val_loss: 0.0113 - val_mae: 0.0859
# Epoch 449/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0109 - mae: 0.0856 - val_loss: 0.0117 - val_mae: 0.0866
# Epoch 450/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0103 - mae: 0.0826 - val_loss: 0.0123 - val_mae: 0.0889
# Epoch 451/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0121 - mae: 0.0876 - val_loss: 0.0110 - val_mae: 0.0856
# Epoch 452/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0103 - mae: 0.0815 - val_loss: 0.0112 - val_mae: 0.0859
# Epoch 453/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0103 - mae: 0.0827 - val_loss: 0.0110 - val_mae: 0.0857
# Epoch 454/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0122 - mae: 0.0896 - val_loss: 0.0111 - val_mae: 0.0860
# Epoch 455/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0111 - mae: 0.0850 - val_loss: 0.0111 - val_mae: 0.0854
# Epoch 456/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0110 - mae: 0.0854 - val_loss: 0.0111 - val_mae: 0.0863
# Epoch 457/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0114 - mae: 0.0861 - val_loss: 0.0117 - val_mae: 0.0869
# Epoch 458/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0112 - mae: 0.0851 - val_loss: 0.0114 - val_mae: 0.0867
# Epoch 459/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0114 - mae: 0.0864 - val_loss: 0.0110 - val_mae: 0.0859
# Epoch 460/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0115 - mae: 0.0860 - val_loss: 0.0113 - val_mae: 0.0864
# Epoch 461/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0106 - mae: 0.0830 - val_loss: 0.0111 - val_mae: 0.0860
# Epoch 462/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0108 - mae: 0.0842 - val_loss: 0.0117 - val_mae: 0.0870
# Epoch 463/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0107 - mae: 0.0842 - val_loss: 0.0120 - val_mae: 0.0874
# Epoch 464/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0128 - mae: 0.0913 - val_loss: 0.0112 - val_mae: 0.0859
# Epoch 465/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0120 - mae: 0.0886 - val_loss: 0.0110 - val_mae: 0.0858
# Epoch 466/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0109 - mae: 0.0850 - val_loss: 0.0112 - val_mae: 0.0867
# Epoch 467/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0116 - mae: 0.0866 - val_loss: 0.0135 - val_mae: 0.0924
# Epoch 468/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0123 - mae: 0.0870 - val_loss: 0.0140 - val_mae: 0.0939
# Epoch 469/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0125 - mae: 0.0914 - val_loss: 0.0112 - val_mae: 0.0860
# Epoch 470/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0117 - mae: 0.0873 - val_loss: 0.0119 - val_mae: 0.0874
# Epoch 471/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0117 - mae: 0.0875 - val_loss: 0.0111 - val_mae: 0.0858
# Epoch 472/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0105 - mae: 0.0830 - val_loss: 0.0114 - val_mae: 0.0863
# Epoch 473/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0109 - mae: 0.0836 - val_loss: 0.0121 - val_mae: 0.0884
# Epoch 474/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0122 - mae: 0.0899 - val_loss: 0.0121 - val_mae: 0.0885
# Epoch 475/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0118 - mae: 0.0870 - val_loss: 0.0115 - val_mae: 0.0869
# Epoch 476/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0108 - mae: 0.0840 - val_loss: 0.0113 - val_mae: 0.0866
# Epoch 477/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0112 - mae: 0.0859 - val_loss: 0.0115 - val_mae: 0.0869
# Epoch 478/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0117 - mae: 0.0865 - val_loss: 0.0114 - val_mae: 0.0858
# Epoch 479/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0119 - mae: 0.0878 - val_loss: 0.0111 - val_mae: 0.0865
# Epoch 480/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0117 - mae: 0.0877 - val_loss: 0.0122 - val_mae: 0.0894
# Epoch 481/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0121 - mae: 0.0876 - val_loss: 0.0113 - val_mae: 0.0866
# Epoch 482/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0111 - mae: 0.0848 - val_loss: 0.0111 - val_mae: 0.0855
# Epoch 483/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0117 - mae: 0.0869 - val_loss: 0.0116 - val_mae: 0.0875
# Epoch 484/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0121 - mae: 0.0888 - val_loss: 0.0118 - val_mae: 0.0876
# Epoch 485/500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0107 - mae: 0.0831 - val_loss: 0.0133 - val_mae: 0.0919
# Epoch 486/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0117 - mae: 0.0874 - val_loss: 0.0110 - val_mae: 0.0854
# Epoch 487/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0108 - mae: 0.0829 - val_loss: 0.0113 - val_mae: 0.0868
# Epoch 488/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0111 - mae: 0.0847 - val_loss: 0.0113 - val_mae: 0.0858
# Epoch 489/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0104 - mae: 0.0825 - val_loss: 0.0120 - val_mae: 0.0879
# Epoch 490/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0117 - mae: 0.0869 - val_loss: 0.0119 - val_mae: 0.0891
# Epoch 491/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0109 - mae: 0.0844 - val_loss: 0.0117 - val_mae: 0.0883
# Epoch 492/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0108 - mae: 0.0851 - val_loss: 0.0112 - val_mae: 0.0867
# Epoch 493/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0113 - mae: 0.0849 - val_loss: 0.0127 - val_mae: 0.0896
# Epoch 494/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0112 - mae: 0.0863 - val_loss: 0.0117 - val_mae: 0.0870
# Epoch 495/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0113 - mae: 0.0858 - val_loss: 0.0121 - val_mae: 0.0879
# Epoch 496/500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0110 - mae: 0.0845 - val_loss: 0.0112 - val_mae: 0.0862
# Epoch 497/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0103 - mae: 0.0810 - val_loss: 0.0111 - val_mae: 0.0860
# Epoch 498/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0113 - mae: 0.0861 - val_loss: 0.0111 - val_mae: 0.0858
# Epoch 499/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0119 - mae: 0.0882 - val_loss: 0.0117 - val_mae: 0.0862
# Epoch 500/500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0111 - mae: 0.0854 - val_loss: 0.0112 - val_mae: 0.0866

# %% [markdown]
# ### 3. Plot Metrics

# %% [markdown]
# **1. Loss (or Mean Squared Error)**
#
# During training, the model's performance is constantly being measured against both our training data and the validation data that we set aside earlier. Training produces a log of data that tells us how the model's performance changed over the course of the training process.
#
# The following cells will display some of that data in a graphical form:

# %%
# Draw a graph of the loss, which is the distance between
# the predicted and actual values during training and validation.
train_loss = history_1.history['loss']
val_loss = history_1.history['val_loss']

epochs = range(1, len(train_loss) + 1)

plt.plot(epochs, train_loss, 'g.', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# The graph shows the _loss_ (or the difference between the model's predictions and the actual data) for each epoch. There are several ways to calculate loss, and the method we have used is _mean squared error_. There is a distinct loss value given for the training and the validation data.
#
# As we can see, the amount of loss rapidly decreases over the first 25 epochs, before flattening out. This means that the model is improving and producing more accurate predictions!
#
# Our goal is to stop training when either the model is no longer improving, or when the _training loss_ is less than the _validation loss_, which would mean that the model has learned to predict the training data so well that it can no longer generalize to new data.
#
# To make the flatter part of the graph more readable, let's skip the first 50 epochs:

# %%
# Exclude the first few epochs so the graph is easier to read
SKIP = 50

plt.plot(epochs[SKIP:], train_loss[SKIP:], 'g.', label='Training loss')
plt.plot(epochs[SKIP:], val_loss[SKIP:], 'b.', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# From the plot, we can see that loss continues to reduce until around 200 epochs, at which point it is mostly stable. This means that there's no need to train our network beyond 200 epochs.
#
# However, we can also see that the lowest loss value is still around 0.155. This means that our network's predictions are off by an average of ~15%. In addition, the validation loss values jump around a lot, and is sometimes even higher.
#
# **2. Mean Absolute Error**
#
# To gain more insight into our model's performance we can plot some more data. This time, we'll plot the _mean absolute error_, which is another way of measuring how far the network's predictions are from the actual numbers:

# %%
plt.clf()

# Draw a graph of mean absolute error, which is another way of
# measuring the amount of error in the prediction.
train_mae = history_1.history['mae']
val_mae = history_1.history['val_mae']

plt.plot(epochs[SKIP:], train_mae[SKIP:], 'g.', label='Training MAE')
plt.plot(epochs[SKIP:], val_mae[SKIP:], 'b.', label='Validation MAE')
plt.title('Training and validation mean absolute error')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %% [markdown]
# This graph of _mean absolute error_ tells another story. We can see that training data shows consistently lower error than validation data, which means that the network may have _overfit_, or learned the training data so rigidly that it can't make effective predictions about new data.
#
# In addition, the mean absolute error values are quite high, ~0.305 at best, which means some of the model's predictions are at least 30% off. A 30% error means we are very far from accurately modelling the sine wave function.
#
# **3. Actual vs Predicted Outputs**
#
# To get more insight into what is happening, let's check its predictions against the test dataset we set aside earlier:

# %%
# Calculate and print the loss on our test dataset
test_loss, test_mae = model_1.evaluate(x_test, y_test)

# Make predictions based on our test dataset
y_test_pred = model_1.predict(x_test)

# Graph the predictions against the actual values
plt.clf()
plt.title('Comparison of predictions and actual values')
plt.plot(x_test, y_test, 'b.', label='Actual values')
plt.plot(x_test, y_test_pred, 'r.', label='TF predictions')
plt.legend()
plt.show()
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0101 - mae: 0.0800

# %% [markdown]
# Oh dear! The graph makes it clear that our network has learned to approximate the sine function in a very limited way.
#
# The rigidity of this fit suggests that the model does not have enough capacity to learn the full complexity of the sine wave function, so it's only able to approximate it in an overly simplistic way. By making our model bigger, we should be able to improve its performance.

# %% [markdown]
# ## Training a Larger Model

# %% [markdown]
# ### 1. Design the Model
# To make our model bigger, let's add an additional layer of neurons. The following cell redefines our model in the same way as earlier, but with 16 neurons in the first layer and an additional layer of 16 neurons in the middle:

# %%
model = tf.keras.Sequential()

# First layer takes a scalar input and feeds it through 16 "neurons". The
# neurons decide whether to activate based on the 'relu' activation function.
model.add(keras.layers.Dense(16, activation='relu', input_shape=(1,)))

# The new second and third layer will help the network learn more complex representations
model.add(keras.layers.Dense(16, activation='relu'))

# Final layer is a single neuron, since we want to output a single value
model.add(keras.layers.Dense(1))

# Compile the model using the standard 'adam' optimizer and the mean squared error or 'mse' loss function for regression.
model.compile(optimizer='adam', loss="mse", metrics=["mae"])

# %% [markdown]
# ### 2. Train the Model ###
#
# We'll now train and save the new model.

# %%
# Train the model
history = model.fit(x_train, y_train, epochs=500, batch_size=64,
                    validation_data=(x_validate, y_validate))

# Save the model to disk
model.save(MODEL_TF)

# %% [markdown]
# ### 3. Plot Metrics
# Each training epoch, the model prints out its loss and mean absolute error for training and validation. You can read this in the output above (note that your exact numbers may differ):
#
# ```
# Epoch 500/500
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0121 - mae: 0.0882 - val_loss: 0.0115 - val_mae: 0.0865
# ```
#
# You can see that we've already got a huge improvement - validation loss has dropped from 0.15 to 0.01, and validation MAE has dropped from 0.33 to 0.08.
#
# The following cell will print the same graphs we used to evaluate our original model, but showing our new training history:

# %%
# Draw a graph of the loss, which is the distance between
# the predicted and actual values during training and validation.
train_loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(train_loss) + 1)

# Exclude the first few epochs so the graph is easier to read
SKIP = 100

plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)

plt.plot(epochs[SKIP:], train_loss[SKIP:], 'g.', label='Training loss')
plt.plot(epochs[SKIP:], val_loss[SKIP:], 'b.', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)

# Draw a graph of mean absolute error, which is another way of
# measuring the amount of error in the prediction.
train_mae = history.history['mae']
val_mae = history.history['val_mae']

plt.plot(epochs[SKIP:], train_mae[SKIP:], 'g.', label='Training MAE')
plt.plot(epochs[SKIP:], val_mae[SKIP:], 'b.', label='Validation MAE')
plt.title('Training and validation mean absolute error')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()

plt.tight_layout()

# %% [markdown]
# Great results! From these graphs, we can see several exciting things:
#
# *   The overall loss and MAE are much better than our previous network
# *   Metrics are better for validation than training, which means the network is not overfitting
#
# The reason the metrics for validation are better than those for training is that validation metrics are calculated at the end of each epoch, while training metrics are calculated throughout the epoch, so validation happens on a model that has been trained slightly longer.
#
# This all means our network seems to be performing well! To confirm, let's check its predictions against the test dataset we set aside earlier:

# %%
# Calculate and print the loss on our test dataset
test_loss, test_mae = model.evaluate(x_test, y_test)

# Make predictions based on our test dataset
y_test_pred = model.predict(x_test)

# Graph the predictions against the actual values
plt.clf()
plt.title('Comparison of predictions and actual values')
plt.plot(x_test, y_test, 'b.', label='Actual values')
plt.plot(x_test, y_test_pred, 'r.', label='TF predicted')
plt.legend()
plt.show()

# %% [markdown]
# Much better! The evaluation metrics we printed show that the model has a low loss and MAE on the test data, and the predictions line up visually with our data fairly well.
#
# The model isn't perfect; its predictions don't form a smooth sine curve. For instance, the line is almost straight when `x` is between 4.2 and 5.2. If we wanted to go further, we could try further increasing the capacity of the model, perhaps using some techniques to defend from overfitting.
#
# However, an important part of machine learning is *knowing when to stop*. This model is good enough for our use case - which is to make some LEDs blink in a pleasing pattern.
#
# ## Generate a TensorFlow Lite Model

# %% [markdown]
# ### 1. Generate Models with or without Quantization
# We now have an acceptably accurate model. We'll use the [TensorFlow Lite Converter](https://www.tensorflow.org/lite/convert) to convert the model into a special, space-efficient format for use on memory-constrained devices.
#
# Since this model is going to be deployed on a microcontroller, we want it to be as tiny as possible! One technique for reducing the size of a model is called [quantization](https://www.tensorflow.org/lite/performance/post_training_quantization). It reduces the precision of the model's weights, and possibly the activations (output of each layer) as well, which saves memory, often without much impact on accuracy. Quantized models also run faster, since the calculations required are simpler.
#
# In the following cell, we'll convert the model twice: once with quantization, once without.

# %%
# Convert the model to the TensorFlow Lite format without quantization
converter = tf.lite.TFLiteConverter.from_saved_model(MODEL_TF)
model_no_quant_tflite = converter.convert()

# Save the model to disk
open(MODEL_NO_QUANT_TFLITE, "wb").write(model_no_quant_tflite)

# Convert the model to the TensorFlow Lite format with quantization
def representative_dataset():
  for i in range(500):
    yield([x_train[i].reshape(1, 1)])
# Set the optimization flag.
converter.optimizations = [tf.lite.Optimize.DEFAULT]
# Enforce integer only quantization
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8
# Provide a representative dataset to ensure we quantize correctly.
converter.representative_dataset = representative_dataset
model_tflite = converter.convert()

# Save the model to disk
open(MODEL_TFLITE, "wb").write(model_tflite)

# %% [markdown]
# ### 2. Compare Model Performance
#
# To prove these models are accurate even after conversion and quantization, we'll compare their predictions and loss on our test dataset.
#
# **Helper functions**
#
# We define the `predict` (for predictions) and `evaluate` (for loss) functions for TFLite models. *Note: These are already included in a TF model, but not in  a TFLite model.*

# %%
def predict_tflite(tflite_model, x_test):
  # Prepare the test data
  x_test_ = x_test.copy()
  x_test_ = x_test_.reshape((x_test.size, 1))
  x_test_ = x_test_.astype(np.float32)

  # Initialize the TFLite interpreter
  interpreter = tf.lite.Interpreter(model_content=tflite_model)
  interpreter.allocate_tensors()

  input_details = interpreter.get_input_details()[0]
  output_details = interpreter.get_output_details()[0]

  # If required, quantize the input layer (from float to integer)
  input_scale, input_zero_point = input_details["quantization"]
  if (input_scale, input_zero_point) != (0.0, 0):
    x_test_ = x_test_ / input_scale + input_zero_point
    x_test_ = x_test_.astype(input_details["dtype"])
  
  # Invoke the interpreter
  y_pred = np.empty(x_test_.size, dtype=output_details["dtype"])
  for i in range(len(x_test_)):
    interpreter.set_tensor(input_details["index"], [x_test_[i]])
    interpreter.invoke()
    y_pred[i] = interpreter.get_tensor(output_details["index"])[0]
  
  # If required, dequantized the output layer (from integer to float)
  output_scale, output_zero_point = output_details["quantization"]
  if (output_scale, output_zero_point) != (0.0, 0):
    y_pred = y_pred.astype(np.float32)
    y_pred = (y_pred - output_zero_point) * output_scale

  return y_pred

def evaluate_tflite(tflite_model, x_test, y_true):
  global model
  y_pred = predict_tflite(tflite_model, x_test)
  loss_function = tf.keras.losses.get(model.loss)
  loss = loss_function(y_true, y_pred).numpy()
  return loss

# %% [markdown]
# **1. Predictions**

# %%
# Calculate predictions
y_test_pred_tf = model.predict(x_test)
y_test_pred_no_quant_tflite = predict_tflite(model_no_quant_tflite, x_test)
y_test_pred_tflite = predict_tflite(model_tflite, x_test)

# %%
# Compare predictions
plt.clf()
plt.title('Comparison of various models against actual values')
plt.plot(x_test, y_test, 'bo', label='Actual values')
plt.plot(x_test, y_test_pred_tf, 'ro', label='TF predictions')
plt.plot(x_test, y_test_pred_no_quant_tflite, 'bx', label='TFLite predictions')
plt.plot(x_test, y_test_pred_tflite, 'gx', label='TFLite quantized predictions')
plt.legend()
plt.show()

# %% [markdown]
# **2. Loss (MSE/Mean Squared Error)**

# %%
# Calculate loss
loss_tf, _ = model.evaluate(x_test, y_test, verbose=0)
loss_no_quant_tflite = evaluate_tflite(model_no_quant_tflite, x_test, y_test)
loss_tflite = evaluate_tflite(model_tflite, x_test, y_test)

# %%
# Compare loss
df = pd.DataFrame.from_records(
    [["TensorFlow", loss_tf],
     ["TensorFlow Lite", loss_no_quant_tflite],
     ["TensorFlow Lite Quantized", loss_tflite]],
     columns = ["Model", "Loss/MSE"], index="Model").round(4)
df

# %% [markdown]
# **3. Size**

# %%
# Calculate size
size_tf = os.path.getsize(MODEL_TF)
size_no_quant_tflite = os.path.getsize(MODEL_NO_QUANT_TFLITE)
size_tflite = os.path.getsize(MODEL_TFLITE)

# %%
# Compare size
pd.DataFrame.from_records(
    [["TensorFlow", f"{size_tf} bytes", ""],
     ["TensorFlow Lite", f"{size_no_quant_tflite} bytes ", f"(reduced by {size_tf - size_no_quant_tflite} bytes)"],
     ["TensorFlow Lite Quantized", f"{size_tflite} bytes", f"(reduced by {size_no_quant_tflite - size_tflite} bytes)"]],
     columns = ["Model", "Size", ""], index="Model")

# %% [markdown]
# **Summary**

# %% [markdown]
# We can see from the predictions (graph) and loss (table) that the original TF model, the TFLite model, and the quantized TFLite model are all close enough to be indistinguishable - even though they differ in size (table). This implies that the quantized (smallest) model is ready to use!
#
# *Note: The quantized (integer) TFLite model is just 300 bytes smaller than the original (float) TFLite model - a tiny reduction in size! This is because the model is already so small that quantization has little effect. Complex models with more weights, can have upto a 4x reduction in size!*

# %% [markdown]
# ## Generate a TensorFlow Lite for Microcontrollers Model
# Convert the TensorFlow Lite quantized model into a C source file that can be loaded by TensorFlow Lite for Microcontrollers.

# %%
# Install xxd if it is not available
# !apt-get update && apt-get -qq install xxd
# Convert to a C source file, i.e, a TensorFlow Lite for Microcontrollers model
# !xxd -i {MODEL_TFLITE} > {MODEL_TFLITE_MICRO}
# Update variable names
REPLACE_TEXT = MODEL_TFLITE.replace('/', '_').replace('.', '_')
# !sed -i 's/'{REPLACE_TEXT}'/g_model/g' {MODEL_TFLITE_MICRO}

# %% [markdown]
# ## Deploy to a Microcontroller
#
# Follow the instructions in the [hello_world](https://github.com/tensorflow/tensorflow/tree/master/tensorflow/lite/micro/examples/hello_world) README.md for [TensorFlow Lite for MicroControllers](https://www.tensorflow.org/lite/microcontrollers/overview) to deploy this model on a specific microcontroller.
#
# **Reference Model:** If you have not modified this notebook, you can follow the instructions as is, to deploy the model. Refer to the [`hello_world/train/models`](https://github.com/tensorflow/tensorflow/blob/master/tensorflow/lite/micro/examples/hello_world/train/models) directory to access the models generated in this notebook.
#
# **New Model:** If you have generated a new model, then update the values assigned to the variables defined in [`hello_world/model.cc`](https://github.com/tensorflow/tensorflow/blob/master/tensorflow/lite/micro/examples/hello_world/model.cc) with values displayed after running the following cell.

# %%
# Print the C source file
# !cat {MODEL_TFLITE_MICRO}
